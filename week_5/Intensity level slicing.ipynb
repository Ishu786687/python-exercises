# %%
import matplotlib.pyplot as plt
from skimage.io import imread
import numpy as np

# %%
src_img = imread('kidney.TIF')

plt.figure(figsize=(5,5))
plt.imshow(src_img, 'gray')
plt.title('Arotic angiogram near kidney area')
plt.show()
